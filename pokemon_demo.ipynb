# %% [markdown]
# # Steps and Important Information
# 1. import the module and function using `from pokemon_game import start_battle`
# 2. call `start_battle()` to begin the game
# 3. have fun!
#
# **Note: Sometimes, the game lasts longer than expected, and Python only displays a limited number of outputs. To clear the previous outputs, type `clear output` when prompted with the next move, and all previous outputs should disappear.**

# %%
# import the function start_battle from pokemon_game module
from pokemon_game import start_battle

# %%
# call the function to start the battle!
start_battle()
# Out:
# Player 1, which Pokemon do you send into battle?
# (If you don't know any, we recommend Charmander, Squirtle, or Bulbasaur!)
#  xerneas
# Player 2, which Pokemon do you send into battle?
# (If you don't know any, we recommend Chikorita, Cyndaquil, or Totodile!)
#  rayquaza
# XERNEAS, choose your move:
# - run
# - attack
# - potion
#  attack
# XERNEAS dealt 8 damage to RAYQUAZA.
# RAYQUAZA, choose your move:
# - run
# - attack
# - potion
#  attack
# RAYQUAZA dealt 71 damage to XERNEAS.
# XERNEAS, choose your move:
# - run
# - attack
# - potion
#  attack
# XERNEAS dealt 50 damage to RAYQUAZA.
# RAYQUAZA, choose your move:
# - run
# - attack
# - potion
#  attack
# RAYQUAZA dealt 29 damage to XERNEAS.
# XERNEAS, choose your move:
# - run
# - attack
# - potion
#  potion
# XERNEAS healed 20 hitpoints!
# XERNEAS used POTION and now has 2 potions left!
# RAYQUAZA, choose your move:
# - run
# - attack
# - potion
#  potion
# RAYQUAZA healed 20 hitpoints!
# ...

# %%
# a rematch!
start_battle()
# Out:
# Player 1, which Pokemon do you send into battle?
# (If you don't know any, we recommend Charmander, Squirtle, or Bulbasaur!)
#  pikachu
# Player 2, which Pokemon do you send into battle?
# (If you don't know any, we recommend Chikorita, Cyndaquil, or Totodile!)
#  charmander
# PIKACHU, choose your move:
# - run
# - attack
# - potion
#  attack
# PIKACHU dealt 19 damage to CHARMANDER.
# CHARMANDER, choose your move:
# - run
# - attack
# - potion
#  attack
# CHARMANDER dealt 29 damage to PIKACHU.
# PIKACHU, choose your move:
# - run
# - attack
# - potion
#  potion
# PIKACHU healed 20 hitpoints!
# PIKACHU used POTION and now has 2 potions left!
# CHARMANDER, choose your move:
# - run
# - attack
# - potion
#  attack
# CHARMANDER dealt 0 damage to PIKACHU.
# PIKACHU, choose your move:
# - run
# - attack
# - potion
#  attack
# PIKACHU dealt 22 damage to CHARMANDER.
# CHARMANDER has fainted! Player 1 won.

# %%
# last battle!
start_battle()
# Out:
# Player 1, which Pokemon do you send into battle?
# (If you don't know any, we recommend Charmander, Squirtle, or Bulbasaur!)
#  reshiram
# Player 2, which Pokemon do you send into battle?
# (If you don't know any, we recommend Chikorita, Cyndaquil, or Totodile!)
#  zekrom
# RESHIRAM, choose your move:
# - run
# - attack
# - potion
#  attack
# RESHIRAM dealt 1 damage to ZEKROM.
# ZEKROM, choose your move:
# - run
# - attack
# - potion
#  attack
# ZEKROM dealt 0 damage to RESHIRAM.
# RESHIRAM, choose your move:
# - run
# - attack
# - potion
#  attack
# RESHIRAM dealt 0 damage to ZEKROM.
# ZEKROM, choose your move:
# - run
# - attack
# - potion
#  attack
# ZEKROM dealt 54 damage to RESHIRAM.
# RESHIRAM, choose your move:
# - run
# - attack
# - potion
#  run
# RESHIRAM has run away
# ZEKROM is victorious!
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ...
