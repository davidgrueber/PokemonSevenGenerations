# %% [markdown]
# # Steps and Important Information
# 1. import the module and function using `from pokemon_game import start_battle`
# 2. call `start_battle()` to begin the game
# 3. have fun!
#
# **Note: Sometimes, the game lasts longer than expected, and Python only displays a limited number of outputs. To clear the previous outputs, type `clear output` when prompted with the next move, and all previous outputs should disappear.**

# %%
# import the function start_battle from pokemon_game module
from pokemon_game import start_battle

# %%
# call the function to start the battle!
start_battle()
# Out:
# Player 1, which Pokemon do you send into battle?
# (If you don't know any, we recommend Charmander, Squirtle, or Bulbasaur!)
#  xerneas
# Player 2, which Pokemon do you send into battle?
# (If you don't know any, we recommend Chikorita, Cyndaquil, or Totodile!)
#  rayquaza
# XERNEAS, choose your move:
# - run
# - attack
# - potion
#  attack
# XERNEAS dealt 64 damage to RAYQUAZA.
# RAYQUAZA, choose your move:
# - run
# - attack
# - potion
#  potion
# RAYQUAZA healed 20 hitpoints!
# RAYQUAZA has 2 potions left!
# XERNEAS, choose your move:
# - run
# - attack
# - potion
#  attack
# XERNEAS dealt 17 damage to RAYQUAZA.
# RAYQUAZA, choose your move:
# - run
# - attack
# - potion
#  attack
# RAYQUAZA dealt 90 damage to XERNEAS.
# XERNEAS, choose your move:
# - run
# - attack
# - potion
#  potion
# XERNEAS healed 20 hitpoints!
# XERNEAS has 2 potions left!
# RAYQUAZA, choose your move:
# - run
# - attack
# - potion
#  attack
# RAYQUAZA dealt 41 damage to XERNEAS.
# XERNEAS, choose your move:
# - run
# - attack
# - potion
#  attack
# XERNEAS dealt 11 damage to RAYQUAZA.
# RAYQUAZA, choose your move:
# - run
# - attack
# - potion
#  attack
# RAYQUAZA dealt 19 damage to XERNEAS.
# XERNEAS has fainted! Player 2 won.

# %%
start_battle()
# Out:
# Player 1, which Pokemon do you send into battle?
# (If you don't know any, we recommend Charmander, Squirtle, or Bulbasaur!)
#  pikachu
# Player 2, which Pokemon do you send into battle?
# (If you don't know any, we recommend Chikorita, Cyndaquil, or Totodile!)
#  cyndaquil
# PIKACHU, choose your move:
# - run
# - attack
# - potion
#  attack
# PIKACHU dealt 11 damage to CYNDAQUIL.
# CYNDAQUIL, choose your move:
# - run
# - attack
# - potion
#  attack
# CYNDAQUIL dealt 27 damage to PIKACHU.
# PIKACHU, choose your move:
# - run
# - attack
# - potion
#  run
# PIKACHU has run away
# CYNDAQUIL is victorious!
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 start_battle()
#
# File ~/Desktop/PIC16A/FinalProjectPokemon/PIC16A_project-main 2/pokemon_game.py:199, in start_battle()
#     196 display_pokemon(player1pokemon.pokemon_name, player1pokemon.hp, player2pokemon.pokemon_name, player2pokemon.hp)
#     198 if turn % 2 == 0:
# --> 199     takeTurn(player1pokemon, player2pokemon)
#     200 else:
#     201     takeTurn(player2pokemon, player1pokemon)
#
# File ~/Desktop/PIC16A/FinalProjectPokemon/PIC16A_project-main 2/pokemon_game.py:153, in start_battle.<locals>.takeTurn(attackingPokemon, defendingPokemon)
#     151 if move == "run":
#     152     attackingPokemon.run(defendingPokemon)
# --> 153     raise Exception("Game is over!")
#     154 elif move == "attack":
#     155     attackingPokemon.useAttack(defendingPokemon)
#
# Exception: Game is over!

# %%
# a rematch!
start_battle()
# Out:
# Player 1, which Pokemon do you send into battle?
# (If you don't know any, we recommend Charmander, Squirtle, or Bulbasaur!)
#  lucario
# Player 2, which Pokemon do you send into battle?
# (If you don't know any, we recommend Chikorita, Cyndaquil, or Totodile!)
#  arceus
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  attack
# LUCARIO dealt 13 damage to ARCEUS.
# ARCEUS, choose your move:
# - run
# - attack
# - potion
#  attack
# ARCEUS dealt 21 damage to LUCARIO.
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  attack
# LUCARIO dealt 27 damage to ARCEUS.
# ARCEUS, choose your move:
# - run
# - attack
# - potion
#  attack
# ARCEUS dealt 41 damage to LUCARIO.
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  potion
# LUCARIO healed 20 hitpoints!
# LUCARIO has 2 potions left!
# ARCEUS, choose your move:
# - run
# - attack
# - potion
#  potion
# ARCEUS healed 20 hitpoints!
# ARCEUS has 2 potions left!
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  potion
# LUCARIO healed 20 hitpoints!
# LUCARIO has 1 potions left!
# ARCEUS, choose your move:
# - run
# - attack
# - potion
#  attack
# ARCEUS dealt 0 damage to LUCARIO.
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  potion
# LUCARIO healed 20 hitpoints!
# LUCARIO has 0 potions left!
# ARCEUS, choose your move:
# - run
# - attack
# - potion
#  attack
# ARCEUS dealt 0 damage to LUCARIO.
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  potion
# All potions have been used! Select another move!
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  attack
# LUCARIO dealt 34 damage to ARCEUS.
# ARCEUS, choose your move:
# - run
# - attack
# - potion
#  attack
# ARCEUS dealt 41 damage to LUCARIO.
# LUCARIO, choose your move:
# - run
# - attack
# - potion
#  attack
# LUCARIO dealt 58 damage to ARCEUS.
# ARCEUS, choose your move:
# - run
# - attack
# - potion
#  attack
# ARCEUS dealt 32 damage to LUCARIO.
# LUCARIO has fainted! Player 2 won.
